# %%
from PIL import Image

# %%
pwd
# Out:
# 'c:\\Users\\lucas\\OneDrive - PUCRS - BR\\Arquivos Aula\\CC\\Projetos\\MyPythonStuff\\Progs_Curso_Udemy\\The Complete Python Bootcamp From Zero to Hero in Python'

# %%
path_imgs = 'c:\\Users\\lucas\\OneDrive - PUCRS - BR\\Arquivos Aula\\CC\\Projetos\\MyPythonStuff\\Progs_Curso_Udemy\\The Complete Python Bootcamp From Zero to Hero in Python\\Other Files and Folders\\Images\\'

# %%
pc = Image.open(path_imgs+'my_computer_image.jpg')

# %%
anita = Image.open(path_imgs+'AnitaanitaB.jpg')

# %%
print(f'Tamanho da imagem: {anita.size}')
# Out:
# Tamanho da imagem: (150, 216)

# %%
w = anita.width/3
h = anita.height/3

# %%
a = anita.crop((0,0,w,h))

# %%
anita.putalpha(128)

# %%
pc.putalpha(128)

# %%
anita.paste(im=pc, box=(0,0),mask=pc)

# %%
anita
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=150x216>

# %%
pc.paste(im=a, box=(50,20),mask=a)

# %%
pc
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x300>
