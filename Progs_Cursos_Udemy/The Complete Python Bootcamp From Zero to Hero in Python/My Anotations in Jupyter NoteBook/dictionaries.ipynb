# %% [markdown]
# HashMaps is used when you want to quickly grab the value when you don't want to know its location

# %%
my_dict = {'key1' : 'value1', 'key2' : 'value2'}

# %% [markdown]
# to get a value just put the key of that value

# %%
my_dict['key1']
# Out:
# 'value1'

# %%
prices_lookup = {'apple' : 2.99, 'oranges' : '1.99', 'milk' : 5.80}

# %%
prices_lookup['apple']
# Out:
# 2.99

# %% [markdown]
# Dictionaries can store any type of variable or even vectors

# %%
d = {'k1' : 2, 'k2': 'asdae', 'k3' : [1,2,3], 'k4' : {'insertKey' : 154}}

# %%
d['k3']
# Out:
# [1, 2, 3]

# %%
d['k4']
# Out:
# {'insertKey': 154}

# %%
d['k4']['insertKey']
# Out:
# 154

# %%
dd = {'k1' : ['a', 'b', 'c']}

# %%
dd['k1'][2].upper()
# Out:
# 'C'

# %%
dd['k1'][2] = dd['k1'][2].upper()

# %%
dd
# Out:
# {'k1': ['a', 'b', 'C']}

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3', 'k4'])

# %%
d.values()
# Out:
# dict_values([2, 'asdae', [1, 2, 3], {'insertKey': 154}])

# %%
d.items()
# Out:
# dict_items([('k1', 2), ('k2', 'asdae'), ('k3', [1, 2, 3]), ('k4', {'insertKey': 154})])
