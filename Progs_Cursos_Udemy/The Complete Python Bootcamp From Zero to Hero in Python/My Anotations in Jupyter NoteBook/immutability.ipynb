# %%
name = "Sam"

# %% [markdown]
# Below are examples of concatenation

# %%
#name[0] = 'P'

# %%
last_name = name[1:]

# %%
last_name
# Out:
# 'am'

# %%
'P'+last_name
# Out:
# 'Pam'

# %%
x = "Hello World"

# %%
x + " it is beautiful outside!"
# Out:
# 'Hello World it is beautiful outside!'

# %%
x = x + " it is beautiful outside!"

# %%
x
# Out:
# 'Hello World it is beautiful outside! it is beautiful outside!'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
x.upper()
# Out:
# 'HELLO WORLD IT IS BEAUTIFUL OUTSIDE! IT IS BEAUTIFUL OUTSIDE!'

# %%
x.lower()
# Out:
# 'hello world it is beautiful outside! it is beautiful outside!'

# %%
x.split()
# Out:
# ['Hello',
#  'World',
#  'it',
#  'is',
#  'beautiful',
#  'outside!',
#  'it',
#  'is',
#  'beautiful',
#  'outside!']

# %%
x = "Hi this is a string"

# %%
x.split('i')
# Out:
# ['H', ' th', 's ', 's a str', 'ng']
